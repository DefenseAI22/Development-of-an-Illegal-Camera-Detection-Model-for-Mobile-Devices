# %%
# 예: 다음 패키지들이 설치되어 있어야 합니다.
# !pip install torch torchvision torchaudio
# !pip install git+https://github.com/facebookresearch/detectron2.git
# !pip install git+https://github.com/aim-uofa/AdelaiDet.git
# (셀 1) AdelaiDet 레포 클론
# !git clone https://github.com/aim-uofa/AdelaiDet.git

# !pip install onnx
# !pip install onnxruntime

# %%
# # (셀 2) 설치 (editable install)
# %cd AdelaiDet
# !pip install -e .
# %cd ..

# %%
import os
import torch

# Detectron2 & AdelaiDet 관련 import
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from adet.config import get_cfg as get_adet_cfg
# from adet.config.defaults import get_cfg as get_adet_cfg

# %% [markdown]
# ## FCOS2onnx

# %%
import torch
import torch.nn as nn

# Detectron2 + AdelaiDet 관련 import
from detectron2.config import get_cfg
from adet.config import get_cfg as get_adet_cfg
from detectron2.engine import DefaultTrainer
from detectron2.checkpoint import DetectionCheckpointer
from detectron2.modeling import build_model

# AdelaiDet FCOS 모델 로드하는 예시 함수
def load_fcos_model(config_path, weight_path, device="cpu"):
    """
    config_path: FCOS_RT/MS_DLA_34_4x_syncbn.yaml 경로
    weight_path: 학습 완료된 model_final.pth 경로

    """
   
    cfg = get_adet_cfg()  # AdelaiDet 전용 cfg
    cfg.merge_from_file("./AdelaiDet/configs/FCOS-Detection/FCOS_RT/MS_DLA_34_4x_syncbn.yaml")
    cfg.MODEL.WEIGHTS = "./model_final.pth"
    cfg.MODEL.DEVICE = "cpu"

    #  # 1) 커스텀 데이터셋 사용 설정
    # cfg.DATASETS.TRAIN = ("custom_train",)
    # cfg.DATASETS.TEST = ("custom_validation",)

    cfg.MODEL.FCOS.NUM_CLASSES = 3
    cfg.MODEL.FPN.IN_FEATURES = ["level1", "level2", "level3", "level4", "level5"]
    cfg.MODEL.FCOS.IN_FEATURES = ["p1", "p2", "p3"]
    cfg.MODEL.FCOS.FPN_STRIDES = [2, 4, 8]
    cfg.MODEL.FCOS.SIZES_OF_INTEREST = [6, 20]
    
    cfg.MODEL.FCOS.NMS_TH = 0.8  # NMS IoU 임계값
    cfg.INPUT.MIN_SIZE_TEST = 640
    cfg.INPUT.MAX_SIZE_TEST = 640
    
    # 모델 생성
    # DefaultTrainer 내부 로직을 이용해 모델만 빌드
    model = build_model(cfg)
    
    # 가중치 로드
    DetectionCheckpointer(model).load("./model_final.pth")
    # DetectionCheckpointer(model).load(weight_path)
    model.eval()
    
    return model


class FCOSInferenceWrapper(nn.Module):
    """
    후처리(NMS 등)를 배제하고, FCOS head의 raw prediction만 반환하는 래퍼.
    """
    def __init__(self, fcos_model, input_shape=(3, 640, 640)):
        super().__init__()
        self.fcos_model = fcos_model
        self.input_shape = input_shape

    def forward(self, images):
        """
        images: (B, 3, H, W) 이미 전처리된 이미지 텐서
        반환값:
          - class_logits (List[Tensor]): 각 FPN 레벨별 (B, C, H, W)
          - box_reg (List[Tensor]): 각 FPN 레벨별 (B, 4, H, W)
          - centerness (List[Tensor]): 각 FPN 레벨별 (B, 1, H, W)
        """
        # 1) Backbone + FPN + Shared Layers 통과한 feature 추출
        # detectron2는 ImageList 구조를 많이 사용하지만, 여기서는 간단히 features만 받아옴
        # 내부적으로 모델 추론 파이프라인을 조금 수정해 사용합니다.
        # 공식적으로는 detectron2의 DefaultPredictor를 그대로 쓰기 어렵기 때문에
        # backbone -> proposal_generator (FCOS) -> forward_head 등을 직접 호출해야 합니다.

        # Feature 추출
        # self.fcos_model.backbone -> features
        # 하지만 AdelaiDet의 FCOS 모델 구조상, 
        # self.fcos_model 는 GeneralizedRCNN 형태일 수 있으므로 
        # 아래와 같이 접근합니다.
        
        # images는 detectron2에서 처리하는 ImageList 형태로 만들어줘야 합니다.
        from detectron2.modeling import build_backbone
        from detectron2.structures import ImageList
        
        # 이미지를 ImageList로 감싸기
        # 크기가 동일한 배치라고 가정
        im_list = ImageList(images, [(self.input_shape[1], self.input_shape[2])]*images.shape[0])
        
        # im_list = ImageList(images, [(images.shape[2], images.shape[3])]*images.shape[0])
        
        
        # backbone 추론
        features = self.fcos_model.backbone(im_list.tensor)
        
        # proposal_generator(FCOS)
        # 여기서 postprocessing이 일어나는 부분을 대신, raw output만 뽑도록 모델 내부 함수를 수정할 수 있어야 합니다.
        # 일반적으로 fcos_model.proposal_generator.forward_head(features, top_module=None)을 호출하면
        # (pred_class_logits, pred_deltas, pred_centerness, top_feats, bbox_towers)가 반환됩니다.
        
        # postprocessing이 없는, FCOSHead의 원본 결과만 받아오기
        pred_class_logits, pred_deltas, pred_centerness, _, _ = \
            self.fcos_model.proposal_generator.forward_head(features, top_module=None)
        
        # List[Tensor] 형태: [P1, P2, P3 … 레벨별 Feature]
        # 각각의 shape: (B, C, H, W)
        return pred_class_logits, pred_deltas, pred_centerness

import os
import torch

def export_fcos_to_onnx(config_path, 
                        weight_path, 
                        onnx_output_path="fcos_raw.onnx",
                        input_height=640, 
                        input_width=640,
                        device="cpu"):

    # 1) 학습된 FCOS 모델 로드
    fcos_model = load_fcos_model(config_path, weight_path, device=device)

    # 2) Wrapper 정의
    wrapper = FCOSInferenceWrapper(fcos_model, 
                                   input_shape=(3, input_height, input_width))
    wrapper.to(device)
    wrapper.eval()

    # 3) 더미 입력(batch_size=1, 3, H, W)
    dummy_input = torch.randn(1, 3, input_height, input_width).to(device)

    # 4) ONNX 변환
    torch.onnx.export(
        wrapper, 
        dummy_input, 
        onnx_output_path,
        input_names=["input"],
        output_names=["class_logits", "box_reg", "centerness"],
        export_params=True,
        opset_version=11,    # opset_version은 필요에 따라 조정
        do_constant_folding=True
    )
    print(f"[INFO] Exported FCOS model (no postprocessing) to ONNX: {onnx_output_path}")


# 실행 예시
if __name__ == "__main__":
    config_path = "./AdelaiDet/configs/FCOS-Detection/FCOS_RT/MS_DLA_34_4x_syncbn.yaml"
    weight_path = "./model_final.pth"
    export_fcos_to_onnx(config_path, weight_path,
                        onnx_output_path="fcos_raw.onnx",
                        device="cpu")  # GPU에서 수행할 경우
# Out:
# WARNING [01/08 18:52:14 d2.config.compat]: Config './AdelaiDet/configs/FCOS-Detection/FCOS_RT/MS_DLA_34_4x_syncbn.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# [01/08 18:52:15 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./model_final.pth ...
# /opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/fvcore/common/checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# [INFO] Exported FCOS model (no postprocessing) to ONNX: fcos_raw.onnx

# %% [markdown]
# ## onnx2tf

# %%
# !pip install onnx onnx2tf
# Out:
# Requirement already satisfied: onnx in /opt/anaconda3/envs/detectron2/lib/python3.9/site-packages (1.17.0)
# Requirement already satisfied: onnx2tf in /opt/anaconda3/envs/detectron2/lib/python3.9/site-packages (1.20.0)
# Requirement already satisfied: numpy>=1.20 in /opt/anaconda3/envs/detectron2/lib/python3.9/site-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/anaconda3/envs/detectron2/lib/python3.9/site-packages (from onnx) (4.25.5)

# %%
# !onnx2tf -i fcos_raw.onnx -o tensorflow_model
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/opt/anaconda3/envs/detectron2/bin/onnx2tf", line 5, in <module>
#     from onnx2tf import main
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/onnx2tf/__init__.py", line 1, in <module>
#     from onnx2tf.onnx2tf import convert, main
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/onnx2tf/onnx2tf.py", line 26, in <module>
#     import tensorflow as tf
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/__init__.py", line 49, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/_api/v2/__internal__/__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__ import autograph
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py", line 8, in <module>
#     from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/python/autograph/core/ag_ctx.py", line 21, in <module>
#     from tensorflow.python.autograph.utils import ag_logging
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/python/autograph/utils/__init__.py", line 17, in <module>
#     from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/python/autograph/utils/context_managers.py", line 19, in <module>
#     from tensorflow.python.framework import ops
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 62, in <module>
#     from tensorflow.python.framework import tensor as tensor_lib
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/python/framework/tensor.py", line 35, in <module>
#     from tensorflow.python.framework import tensor_util
#   File "/opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/tensorflow/python/framework/tensor_util.py", line 39, in <module>
#     from tensorflow.python.framework import fast_tensor_util
#
# Model optimizing started ============================================================
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add                   │ 40             │ 40               │
# │ Concat                │ 6              │ 6                │
# │ Constant              │ 211            │ 139              │
# │ Conv                  │ 78             │ 78               │
# │ Identity              │ 32             │ 0                │
# │ InstanceNormalization │ 24             │ 24               │
# │ MaxPool               │ 6              │ 4                │
# │ Mul                   │ 27             │ 27               │
# │ Relu                  │ 60             │ 60               │
# │ Reshape               │ 48             │ 48               │
# │ Resize                │ 4              │ 4                │
# │ Shape                 │ 24             │ 0                │
# │ Model Size            │ 84.0MiB        │ 84.0MiB          │
# └───────────────────────┴────────────────┴──────────────────┘
#
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add                   │ 40             │ 40               │
# │ Concat                │ 6              │ 6                │
# │ Constant              │ 139            │ 139              │
# │ Conv                  │ 78             │ 78               │
# │ InstanceNormalization │ 24             │ 24               │
# │ MaxPool               │ 4              │ 4                │
# │ Mul                   │ 27             │ 27               │
# │ Relu                  │ 60             │ 60               │
# │ Reshape               │ 48             │ 48               │
# │ Resize                │ 4              │ 4                │
# │ Model Size            │ 84.0MiB        │ 84.0MiB          │
# └───────────────────────┴────────────────┴──────────────────┘
#
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                       ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add                   │ 40             │ 40               │
# │ Concat                │ 6              │ 6                │
# │ Constant              │ 139            │ 139              │
# │ Conv                  │ 78             │ 78               │
# │ InstanceNormalization │ 24             │ 24               │
# │ MaxPool               │ 4              │ 4                │
# │ Mul                   │ 27             │ 27               │
# │ Relu                  │ 60             │ 60               │
# │ Reshape               │ 48             │ 48               │
# │ Resize                │ 4              │ 4                │
# │ Model Size            │ 84.0MiB        │ 84.0MiB          │
# └───────────────────────┴────────────────┴──────────────────┘
#
# Model optimizing complete!
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: input shape: [1, 3, 640, 640] dtype: float32
# WARNING: The optimization process for shape estimation is skipped because it contains OPs that cannot be inferred by the standard onnxruntime.
# WARNING: The tool skipped dummy inference to avoid SWAP processing because the total size of the tensor of inference results exceeded about 4.0 GB. (results: 8 GB)
#
# INFO: 2 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/base_layer/base_layer.0/Conv
# INFO:  input_name.1: input shape: [1, 3, 640, 640] dtype: float32
# INFO:  input_name.2: onnx::Conv_787 shape: [16, 3, 7, 7] dtype: float32
# INFO:  input_name.3: onnx::Conv_788 shape: [16] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/base_layer/base_layer.0/Conv_output_0 shape: [1, 16, 640, 640] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: input shape: (1, 640, 640, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (7, 7, 3, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (1, 640, 640, 16) dtype: <dtype: 'float32'>
#
# INFO: 3 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/base_layer/base_layer.2/Relu
# INFO:  input_name.1: /backbone/bottom_up/base_layer/base_layer.0/Conv_output_0 shape: [1, 16, 640, 640] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/base_layer/base_layer.2/Relu_output_0 shape: [1, 16, 640, 640] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add/Add:0 shape: (1, 640, 640, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu/Relu:0 shape: (1, 640, 640, 16) dtype: <dtype: 'float32'>
#
# INFO: 4 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level0/level0.0/Conv
# INFO:  input_name.1: /backbone/bottom_up/base_layer/base_layer.2/Relu_output_0 shape: [1, 16, 640, 640] dtype: float32
# INFO:  input_name.2: onnx::Conv_790 shape: [16, 16, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_791 shape: [16] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level0/level0.0/Conv_output_0 shape: [1, 16, 640, 640] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu/Relu:0 shape: (1, 640, 640, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_1/Add:0 shape: (1, 640, 640, 16) dtype: <dtype: 'float32'>
#
# INFO: 5 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level0/level0.2/Relu
# INFO:  input_name.1: /backbone/bottom_up/level0/level0.0/Conv_output_0 shape: [1, 16, 640, 640] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level0/level0.2/Relu_output_0 shape: [1, 16, 640, 640] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_1/Add:0 shape: (1, 640, 640, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_1/Relu:0 shape: (1, 640, 640, 16) dtype: <dtype: 'float32'>
#
# INFO: 6 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level1/level1.0/Conv
# INFO:  input_name.1: /backbone/bottom_up/level0/level0.2/Relu_output_0 shape: [1, 16, 640, 640] dtype: float32
# INFO:  input_name.2: onnx::Conv_793 shape: [32, 16, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_794 shape: [32] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level1/level1.0/Conv_output_0 shape: [1, 32, 320, 320] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad/Pad:0 shape: (1, 642, 642, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_2/Add:0 shape: (1, 320, 320, 32) dtype: <dtype: 'float32'>
#
# INFO: 7 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level1/level1.2/Relu
# INFO:  input_name.1: /backbone/bottom_up/level1/level1.0/Conv_output_0 shape: [1, 32, 320, 320] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level1/level1.2/Relu_output_0 shape: [1, 32, 320, 320] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_2/Add:0 shape: (1, 320, 320, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_2/Relu:0 shape: (1, 320, 320, 32) dtype: <dtype: 'float32'>
#
# INFO: 8 / 292
# INFO: onnx_op_type: MaxPool onnx_op_name: /backbone/bottom_up/level2/downsample/MaxPool
# INFO:  input_name.1: /backbone/bottom_up/level1/level1.2/Relu_output_0 shape: [1, 32, 320, 320] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/downsample/MaxPool_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_2/Relu:0 shape: (1, 320, 320, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d/MaxPool2d:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 9 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level2/tree1/conv1/Conv
# INFO:  input_name.1: /backbone/bottom_up/level1/level1.2/Relu_output_0 shape: [1, 32, 320, 320] dtype: float32
# INFO:  input_name.2: onnx::Conv_799 shape: [64, 32, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_800 shape: [64] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree1/conv1/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_1/Pad:0 shape: (1, 322, 322, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_3/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 10 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/fpn_lateral1/Conv
# INFO:  input_name.1: /backbone/bottom_up/level1/level1.2/Relu_output_0 shape: [1, 32, 320, 320] dtype: float32
# INFO:  input_name.2: fcos_model.backbone.fpn_lateral1.weight shape: [256, 32, 1, 1] dtype: float32
# INFO:  input_name.3: fcos_model.backbone.fpn_lateral1.bias shape: [256] dtype: float32
# INFO:  output_name.1: /backbone/fpn_lateral1/Conv_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_2/Relu:0 shape: (1, 320, 320, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 32, 256) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (256,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_4/Add:0 shape: (1, 320, 320, 256) dtype: <dtype: 'float32'>
#
# INFO: 11 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level2/project/project.0/Conv
# INFO:  input_name.1: /backbone/bottom_up/level2/downsample/MaxPool_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: onnx::Conv_796 shape: [64, 32, 1, 1] dtype: float32
# INFO:  input_name.3: onnx::Conv_797 shape: [64] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/project/project.0/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.max_pool2d/MaxPool2d:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 32, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_5/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 12 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level2/tree1/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level2/tree1/conv1/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree1/relu/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_3/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_3/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 13 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level2/tree1/conv2/Conv
# INFO:  input_name.1: /backbone/bottom_up/level2/tree1/relu/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: onnx::Conv_802 shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_803 shape: [64] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree1/conv2/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_3/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_6/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 14 / 292
# INFO: onnx_op_type: Add onnx_op_name: /backbone/bottom_up/level2/tree1/Add
# INFO:  input_name.1: /backbone/bottom_up/level2/tree1/conv2/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level2/project/project.0/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree1/Add_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_6/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_5/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_7/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 15 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level2/tree1/relu_1/Relu
# INFO:  input_name.1: /backbone/bottom_up/level2/tree1/Add_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree1/relu_1/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_7/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_4/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 16 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level2/tree2/conv1/Conv
# INFO:  input_name.1: /backbone/bottom_up/level2/tree1/relu_1/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: onnx::Conv_805 shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_806 shape: [64] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree2/conv1/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_4/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_8/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 17 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level2/tree2/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level2/tree2/conv1/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree2/relu/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_8/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_5/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 18 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level2/tree2/conv2/Conv
# INFO:  input_name.1: /backbone/bottom_up/level2/tree2/relu/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: onnx::Conv_808 shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_809 shape: [64] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree2/conv2/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_5/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_9/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 19 / 292
# INFO: onnx_op_type: Add onnx_op_name: /backbone/bottom_up/level2/tree2/Add
# INFO:  input_name.1: /backbone/bottom_up/level2/tree2/conv2/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level2/tree1/relu_1/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree2/Add_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_9/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.nn.relu_4/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_10/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 20 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level2/tree2/relu_1/Relu
# INFO:  input_name.1: /backbone/bottom_up/level2/tree2/Add_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/tree2/relu_1/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_10/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_6/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 21 / 292
# INFO: onnx_op_type: Concat onnx_op_name: /backbone/bottom_up/level2/root/Concat
# INFO:  input_name.1: /backbone/bottom_up/level2/tree2/relu_1/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level2/tree1/relu_1/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/root/Concat_output_0 shape: [1, 128, 160, 160] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.nn.relu_6/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.nn.relu_4/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 3
# INFO:  output.1.output: name: tf.concat/concat:0 shape: (1, 160, 160, 128) dtype: <dtype: 'float32'>
#
# INFO: 22 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level2/root/conv/Conv
# INFO:  input_name.1: /backbone/bottom_up/level2/root/Concat_output_0 shape: [1, 128, 160, 160] dtype: float32
# INFO:  input_name.2: onnx::Conv_811 shape: [64, 128, 1, 1] dtype: float32
# INFO:  input_name.3: onnx::Conv_812 shape: [64] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/root/conv/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat/concat:0 shape: (1, 160, 160, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_11/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 23 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level2/root/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level2/root/conv/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level2/root/relu/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_11/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_7/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 24 / 292
# INFO: onnx_op_type: MaxPool onnx_op_name: /backbone/bottom_up/level3/downsample/MaxPool
# INFO:  input_name.1: /backbone/bottom_up/level2/root/relu/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/downsample/MaxPool_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_7/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d_1/MaxPool2d:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 25 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree1/tree1/conv1/Conv
# INFO:  input_name.1: /backbone/bottom_up/level2/root/relu/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: onnx::Conv_817 shape: [128, 64, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_818 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree1/conv1/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_2/Pad:0 shape: (1, 162, 162, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_12/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 26 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/fpn_lateral2/Conv
# INFO:  input_name.1: /backbone/bottom_up/level2/root/relu/Relu_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: fcos_model.backbone.fpn_lateral2.weight shape: [256, 64, 1, 1] dtype: float32
# INFO:  input_name.3: fcos_model.backbone.fpn_lateral2.bias shape: [256] dtype: float32
# INFO:  output_name.1: /backbone/fpn_lateral2/Conv_output_0 shape: [1, 256, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_7/Relu:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 256) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (256,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_13/Add:0 shape: (1, 160, 160, 256) dtype: <dtype: 'float32'>
#
# INFO: 27 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree1/project/project.0/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/downsample/MaxPool_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_814 shape: [128, 64, 1, 1] dtype: float32
# INFO:  input_name.3: onnx::Conv_815 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/project/project.0/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.max_pool2d_1/MaxPool2d:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_14/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 28 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree1/tree1/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree1/conv1/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree1/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_12/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_8/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 29 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree1/tree1/conv2/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree1/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_820 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_821 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree1/conv2/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_8/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_15/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 30 / 292
# INFO: onnx_op_type: Add onnx_op_name: /backbone/bottom_up/level3/tree1/tree1/Add
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree1/conv2/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level3/tree1/project/project.0/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree1/Add_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_15/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_14/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_16/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 31 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree1/tree1/relu_1/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree1/Add_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree1/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_16/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_9/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 32 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree1/tree2/conv1/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree1/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_823 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_824 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree2/conv1/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_9/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_17/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 33 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree1/tree2/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree2/conv1/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree2/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_17/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_10/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 34 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree1/tree2/conv2/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree2/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_826 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_827 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree2/conv2/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_10/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_18/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 35 / 292
# INFO: onnx_op_type: Add onnx_op_name: /backbone/bottom_up/level3/tree1/tree2/Add
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree2/conv2/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level3/tree1/tree1/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree2/Add_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_18/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.nn.relu_9/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_19/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 36 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree1/tree2/relu_1/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree2/Add_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/tree2/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_19/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_11/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 37 / 292
# INFO: onnx_op_type: Concat onnx_op_name: /backbone/bottom_up/level3/tree1/root/Concat
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/tree2/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level3/tree1/tree1/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/root/Concat_output_0 shape: [1, 256, 80, 80] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.nn.relu_11/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.nn.relu_9/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 3
# INFO:  output.1.output: name: tf.concat_1/concat:0 shape: (1, 80, 80, 256) dtype: <dtype: 'float32'>
#
# INFO: 38 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree1/root/conv/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/root/Concat_output_0 shape: [1, 256, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_829 shape: [128, 256, 1, 1] dtype: float32
# INFO:  input_name.3: onnx::Conv_830 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/root/conv/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_1/concat:0 shape: (1, 80, 80, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 256, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_20/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 39 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree1/root/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/root/conv/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree1/root/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_20/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_12/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 40 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree2/tree1/conv1/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree1/root/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_832 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_833 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree1/conv1/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_12/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_21/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 41 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree2/tree1/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree1/conv1/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree1/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_21/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_13/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 42 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree2/tree1/conv2/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree1/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_835 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_836 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree1/conv2/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_13/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_22/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 43 / 292
# INFO: onnx_op_type: Add onnx_op_name: /backbone/bottom_up/level3/tree2/tree1/Add
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree1/conv2/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level3/tree1/root/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree1/Add_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_22/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.nn.relu_12/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_23/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 44 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree2/tree1/relu_1/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree1/Add_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree1/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_23/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_14/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 45 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree2/tree2/conv1/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree1/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_838 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_839 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree2/conv1/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_14/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_24/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 46 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree2/tree2/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree2/conv1/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree2/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_24/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_15/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 47 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree2/tree2/conv2/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree2/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_841 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_842 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree2/conv2/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_15/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_25/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 48 / 292
# INFO: onnx_op_type: Add onnx_op_name: /backbone/bottom_up/level3/tree2/tree2/Add
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree2/conv2/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level3/tree2/tree1/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree2/Add_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_25/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.nn.relu_14/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_26/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 49 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree2/tree2/relu_1/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree2/Add_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/tree2/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_26/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_16/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 50 / 292
# INFO: onnx_op_type: Concat onnx_op_name: /backbone/bottom_up/level3/tree2/root/Concat
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/tree2/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: /backbone/bottom_up/level3/tree2/tree1/relu_1/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.3: /backbone/bottom_up/level3/downsample/MaxPool_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.4: /backbone/bottom_up/level3/tree1/root/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/root/Concat_output_0 shape: [1, 448, 80, 80] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.nn.relu_16/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.nn.relu_14/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.nn.max_pool2d_1/MaxPool2d:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.4.input3: name: tf.nn.relu_12/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.5.axis: val: 3
# INFO:  output.1.output: name: tf.concat_2/concat:0 shape: (1, 80, 80, 448) dtype: <dtype: 'float32'>
#
# INFO: 51 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /backbone/bottom_up/level3/tree2/root/conv/Conv
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/root/Concat_output_0 shape: [1, 448, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Conv_844 shape: [128, 448, 1, 1] dtype: float32
# INFO:  input_name.3: onnx::Conv_845 shape: [128] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/root/conv/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_2/concat:0 shape: (1, 80, 80, 448) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 448, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_27/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 52 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /backbone/bottom_up/level3/tree2/root/relu/Relu
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/root/conv/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level3/tree2/root/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_27/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_17/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 53 / 292
# INFO: onnx_op_type: MaxPool onnx_op_name: /backbone/bottom_up/level4/downsample/MaxPool
# INFO:  input_name.1: /backbone/bottom_up/level3/tree2/root/relu/Relu_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /backbone/bottom_up/level4/downsample/MaxPool_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_17/Relu:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# ...
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_109/Add:0 shape: (1, 80, 80, 4) dtype: <dtype: 'float32'>
#
# INFO: 273 / 292
# INFO: onnx_op_type: Mul onnx_op_name: /fcos_head/cls_tower/cls_tower.10/Mul
# INFO:  input_name.1: /fcos_head/cls_tower/cls_tower.10/Reshape_1_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  input_name.2: onnx::Mul_907 shape: (256, 1, 1) dtype: float32
# INFO:  output_name.1: /fcos_head/cls_tower/cls_tower.10/Mul_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.reshape_46/Reshape:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 256, 1, 1) dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_150/Mul:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
#
# INFO: 274 / 292
# INFO: onnx_op_type: Mul onnx_op_name: /fcos_head/bbox_tower/bbox_tower.10/Mul
# INFO:  input_name.1: /fcos_head/bbox_tower/bbox_tower.10/Reshape_1_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  input_name.2: onnx::Mul_915 shape: (256, 1, 1) dtype: float32
# INFO:  output_name.1: /fcos_head/bbox_tower/bbox_tower.10/Mul_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.reshape_47/Reshape:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 256, 1, 1) dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_151/Mul:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
#
# INFO: 275 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /fcos_head/cls_tower/cls_tower.11_1/Relu
# INFO:  input_name.1: /fcos_head/cls_tower/cls_tower.10_1/Add_output_0 shape: [1, 256, 160, 160] dtype: float32
# INFO:  output_name.1: /fcos_head/cls_tower/cls_tower.11_1/Relu_output_0 shape: [1, 256, 160, 160] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_105/Add:0 shape: (1, 256, 160, 160) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_53/Relu:0 shape: (1, 256, 160, 160) dtype: <dtype: 'float32'>
#
# INFO: 276 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /fcos_head/bbox_tower/bbox_tower.11_1/Relu
# INFO:  input_name.1: /fcos_head/bbox_tower/bbox_tower.10_1/Add_output_0 shape: [1, 256, 160, 160] dtype: float32
# INFO:  output_name.1: /fcos_head/bbox_tower/bbox_tower.11_1/Relu_output_0 shape: [1, 256, 160, 160] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_106/Add:0 shape: (1, 256, 160, 160) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_54/Relu:0 shape: (1, 256, 160, 160) dtype: <dtype: 'float32'>
#
# INFO: 277 / 292
# INFO: onnx_op_type: Mul onnx_op_name: /fcos_head/scales.2/Mul
# INFO:  input_name.1: /fcos_head/bbox_pred_2/Conv_output_0 shape: [1, 4, 80, 80] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.scales.2.scale shape: [1] dtype: float32
# INFO:  output_name.1: /fcos_head/scales.2/Mul_output_0 shape: [1, 4, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_109/Add:0 shape: (1, 80, 80, 4) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_152/Mul:0 shape: (1, 80, 80, 4) dtype: <dtype: 'float32'>
#
# INFO: 278 / 292
# INFO: onnx_op_type: Add onnx_op_name: /fcos_head/cls_tower/cls_tower.10/Add
# INFO:  input_name.1: /fcos_head/cls_tower/cls_tower.10/Mul_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  input_name.2: onnx::Add_908 shape: (256, 1, 1) dtype: float32
# INFO:  output_name.1: /fcos_head/cls_tower/cls_tower.10/Add_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.multiply_150/Mul:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 256, 1, 1) dtype: float32
# INFO:  output.1.output: name: tf.math.add_110/Add:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
#
# INFO: 279 / 292
# INFO: onnx_op_type: Add onnx_op_name: /fcos_head/bbox_tower/bbox_tower.10/Add
# INFO:  input_name.1: /fcos_head/bbox_tower/bbox_tower.10/Mul_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  input_name.2: onnx::Add_916 shape: (256, 1, 1) dtype: float32
# INFO:  output_name.1: /fcos_head/bbox_tower/bbox_tower.10/Add_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.multiply_151/Mul:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 256, 1, 1) dtype: float32
# INFO:  output.1.output: name: tf.math.add_111/Add:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
#
# INFO: 280 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /fcos_head/cls_logits_1/Conv
# INFO:  input_name.1: /fcos_head/cls_tower/cls_tower.11_1/Relu_output_0 shape: [1, 256, 160, 160] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.cls_logits.weight shape: (3, 256, 3, 3) dtype: float32
# INFO:  input_name.3: fcos_model.proposal_generator.fcos_head.cls_logits.bias shape: (3,) dtype: float32
# INFO:  output_name.1: box_reg shape: [1, 3, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_213/transpose:0 shape: (1, 160, 160, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 3) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (3,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_112/Add:0 shape: (1, 160, 160, 3) dtype: <dtype: 'float32'>
#
# INFO: 281 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /fcos_head/ctrness_1/Conv
# INFO:  input_name.1: /fcos_head/bbox_tower/bbox_tower.11_1/Relu_output_0 shape: [1, 256, 160, 160] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.ctrness.weight shape: (1, 256, 3, 3) dtype: float32
# INFO:  input_name.3: fcos_model.proposal_generator.fcos_head.ctrness.bias shape: (1,) dtype: float32
# INFO:  output_name.1: 673 shape: [1, 1, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_214/transpose:0 shape: (1, 160, 160, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (1,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_113/Add:0 shape: (1, 160, 160, 1) dtype: <dtype: 'float32'>
#
# INFO: 282 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /fcos_head/bbox_pred_1/Conv
# INFO:  input_name.1: /fcos_head/bbox_tower/bbox_tower.11_1/Relu_output_0 shape: [1, 256, 160, 160] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.bbox_pred.weight shape: (4, 256, 3, 3) dtype: float32
# INFO:  input_name.3: fcos_model.proposal_generator.fcos_head.bbox_pred.bias shape: (4,) dtype: float32
# INFO:  output_name.1: /fcos_head/bbox_pred_1/Conv_output_0 shape: [1, 4, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_215/transpose:0 shape: (1, 160, 160, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 4) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (4,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_114/Add:0 shape: (1, 160, 160, 4) dtype: <dtype: 'float32'>
#
# INFO: 283 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /fcos_head/Relu_2
# INFO:  input_name.1: /fcos_head/scales.2/Mul_output_0 shape: [1, 4, 80, 80] dtype: float32
# INFO:  output_name.1: 785 shape: [1, 4, 80, 80] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.multiply_152/Mul:0 shape: (1, 80, 80, 4) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_55/Relu:0 shape: (1, 80, 80, 4) dtype: <dtype: 'float32'>
#
# INFO: 284 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /fcos_head/cls_tower/cls_tower.11/Relu
# INFO:  input_name.1: /fcos_head/cls_tower/cls_tower.10/Add_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  output_name.1: /fcos_head/cls_tower/cls_tower.11/Relu_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_110/Add:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_56/Relu:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
#
# INFO: 285 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /fcos_head/bbox_tower/bbox_tower.11/Relu
# INFO:  input_name.1: /fcos_head/bbox_tower/bbox_tower.10/Add_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  output_name.1: /fcos_head/bbox_tower/bbox_tower.11/Relu_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_111/Add:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_57/Relu:0 shape: (1, 256, 320, 320) dtype: <dtype: 'float32'>
#
# INFO: 286 / 292
# INFO: onnx_op_type: Mul onnx_op_name: /fcos_head/scales.1/Mul
# INFO:  input_name.1: /fcos_head/bbox_pred_1/Conv_output_0 shape: [1, 4, 160, 160] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.scales.1.scale shape: [1] dtype: float32
# INFO:  output_name.1: /fcos_head/scales.1/Mul_output_0 shape: [1, 4, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_114/Add:0 shape: (1, 160, 160, 4) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_153/Mul:0 shape: (1, 160, 160, 4) dtype: <dtype: 'float32'>
#
# INFO: 287 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /fcos_head/cls_logits/Conv
# INFO:  input_name.1: /fcos_head/cls_tower/cls_tower.11/Relu_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.cls_logits.weight shape: (3, 256, 3, 3) dtype: float32
# INFO:  input_name.3: fcos_model.proposal_generator.fcos_head.cls_logits.bias shape: (3,) dtype: float32
# INFO:  output_name.1: class_logits shape: [1, 3, 320, 320] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_216/transpose:0 shape: (1, 320, 320, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 3) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (3,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_115/Add:0 shape: (1, 320, 320, 3) dtype: <dtype: 'float32'>
#
# INFO: 288 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /fcos_head/ctrness/Conv
# INFO:  input_name.1: /fcos_head/bbox_tower/bbox_tower.11/Relu_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.ctrness.weight shape: (1, 256, 3, 3) dtype: float32
# INFO:  input_name.3: fcos_model.proposal_generator.fcos_head.ctrness.bias shape: (1,) dtype: float32
# INFO:  output_name.1: 564 shape: [1, 1, 320, 320] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_217/transpose:0 shape: (1, 320, 320, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (1,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_116/Add:0 shape: (1, 320, 320, 1) dtype: <dtype: 'float32'>
#
# INFO: 289 / 292
# INFO: onnx_op_type: Conv onnx_op_name: /fcos_head/bbox_pred/Conv
# INFO:  input_name.1: /fcos_head/bbox_tower/bbox_tower.11/Relu_output_0 shape: [1, 256, 320, 320] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.bbox_pred.weight shape: (4, 256, 3, 3) dtype: float32
# INFO:  input_name.3: fcos_model.proposal_generator.fcos_head.bbox_pred.bias shape: (4,) dtype: float32
# INFO:  output_name.1: /fcos_head/bbox_pred/Conv_output_0 shape: [1, 4, 320, 320] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_218/transpose:0 shape: (1, 320, 320, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 4) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (4,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_117/Add:0 shape: (1, 320, 320, 4) dtype: <dtype: 'float32'>
#
# INFO: 290 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /fcos_head/Relu_1
# INFO:  input_name.1: /fcos_head/scales.1/Mul_output_0 shape: [1, 4, 160, 160] dtype: float32
# INFO:  output_name.1: 676 shape: [1, 4, 160, 160] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.multiply_153/Mul:0 shape: (1, 160, 160, 4) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_58/Relu:0 shape: (1, 160, 160, 4) dtype: <dtype: 'float32'>
#
# INFO: 291 / 292
# INFO: onnx_op_type: Mul onnx_op_name: /fcos_head/scales.0/Mul
# INFO:  input_name.1: /fcos_head/bbox_pred/Conv_output_0 shape: [1, 4, 320, 320] dtype: float32
# INFO:  input_name.2: fcos_model.proposal_generator.fcos_head.scales.0.scale shape: [1] dtype: float32
# INFO:  output_name.1: /fcos_head/scales.0/Mul_output_0 shape: [1, 4, 320, 320] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_117/Add:0 shape: (1, 320, 320, 4) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_154/Mul:0 shape: (1, 320, 320, 4) dtype: <dtype: 'float32'>
#
# INFO: 292 / 292
# INFO: onnx_op_type: Relu onnx_op_name: /fcos_head/Relu
# INFO:  input_name.1: /fcos_head/scales.0/Mul_output_0 shape: [1, 4, 320, 320] dtype: float32
# INFO:  output_name.1: 567 shape: [1, 4, 320, 320] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.multiply_154/Mul:0 shape: (1, 320, 320, 4) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_59/Relu:0 shape: (1, 320, 320, 4) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# saved_model output complete!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736330245.652281 8018105 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736330245.653121 8018105 single_machine.cc:361] Starting new session
# W0000 00:00:1736330246.911239 8018105 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1736330246.911256 8018105 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Float32 tflite output complete!
# I0000 00:00:1736330248.087500 8018105 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# I0000 00:00:1736330248.087574 8018105 single_machine.cc:361] Starting new session
# W0000 00:00:1736330249.094439 8018105 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1736330249.094455 8018105 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Float16 tflite output complete!

# %% [markdown]
# ## 변환 비교 확인

# %%
import os
import cv2
import numpy as np
import torch
import torch.nn as nn

# Detectron2 + AdelaiDet import
from detectron2.config import get_cfg
from adet.config import get_cfg as get_adet_cfg
from detectron2.modeling import build_model
from detectron2.checkpoint import DetectionCheckpointer
from detectron2.structures import ImageList

import onnxruntime as ort
import tensorflow as tf



#############################################
# 실제 이미지 로드 & 전처리
#############################################
def load_and_preprocess_image(image_path, target_size=640):
    """
    - image_path에 있는 이미지를 로드하여 (640, 640) 크기로 리사이즈
    - BGR->RGB 변환 (OpenCV는 BGR로 로드)
    - (1, 3, H, W) PyTorch 텐서로 변환
    """
    # 1) 이미지 로드 (OpenCV: BGR)
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        raise FileNotFoundError(f"Image not found: {image_path}")
    
    # 2) 리사이즈
    img_bgr = cv2.resize(img_bgr, (target_size, target_size))

    # 3) BGR -> RGB
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    # 4) (H, W, 3) -> (3, H, W)
    img_rgb = np.transpose(img_rgb, (2, 0, 1))  # (3,640,640)

    # 5) float32 변환
    img_rgb = img_rgb.astype(np.float32)

    # (선택) 정규화: ex) 이미지 픽셀(0~255)을 [0,1] 범위로 맞춤
    # img_rgb /= 255.0

    # 6) 배치 차원 추가 -> (1,3,640,640)
    img_tensor = torch.from_numpy(img_rgb).unsqueeze(0)
    
    return img_tensor  # PyTorch 텐서 반환


#############################################
#  MSE 계산 함수
#############################################
def mse(a, b):
    return np.mean((a - b)**2)

# %%
#############################################
# 메인 테스트 예시
#############################################
if __name__ == "__main__":
    # ------------------------------------------------------
    # (A) 모델 로드
    # ------------------------------------------------------
    config_path = "./AdelaiDet/configs/FCOS-Detection/FCOS_RT/MS_DLA_34_4x_syncbn.yaml"
    weight_path = "./model_final.pth"
    device = "cpu"  # or "cuda"

    # Detectron2+AdelaiDet FCOS 모델 로드
    base_fcos_model = load_fcos_model(config_path, weight_path, device=device)

    # 후처리 없이 raw head만 추론하는 래퍼
    fcos_wrapper = FCOSInferenceWrapper(base_fcos_model).to(device)
    fcos_wrapper.eval()

    # ------------------------------------------------------
    # (B) 실제 이미지 로드 & 전처리
    # ------------------------------------------------------
    image_path = "./Dataset/IMG_8457.JPG"  # 실제 테스트할 이미지 경로
    image_tensor = load_and_preprocess_image(image_path, target_size=640)
    image_tensor = image_tensor.to(device)  # GPU 사용 시 .to("cuda")
    
    # ------------------------------------------------------
    # (C) PyTorch로 Raw Output 추론
    # ------------------------------------------------------
    with torch.no_grad():
        pt_class_logits_list, pt_box_reg_list, pt_centerness_list = fcos_wrapper(image_tensor)

    pt_class_np = [x.cpu().numpy() for x in pt_class_logits_list]
    pt_box_np   = [x.cpu().numpy() for x in pt_box_reg_list]
    pt_center_np= [x.cpu().numpy() for x in pt_centerness_list]

    # ------------------------------------------------------
    # (D) ONNX Runtime 추론
    # ------------------------------------------------------
    onnx_session = ort.InferenceSession("fcos_raw.onnx", providers=["CPUExecutionProvider"])

    # ONNX 입력은 (1,3,640,640) 형태
    onnx_inputs = {onnx_session.get_inputs()[0].name: image_tensor.cpu().numpy()}
    onnx_outputs = onnx_session.run(None, onnx_inputs)
    # 보통 9개 텐서가 [0:3], [3:6], [6:9] 으로 class, box, center
    
    onnx_class_np   = onnx_outputs[0:3]
    onnx_box_np     = onnx_outputs[3:6]
    onnx_center_np  = onnx_outputs[6:9]

    # ------------------------------------------------------
    # (E) TFLite 추론
    # ------------------------------------------------------
    tflite_path = "./tensorflow_model/fcos_raw_float32.tflite"
    interpreter = tf.lite.Interpreter(model_path=tflite_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    # TFLite는 (1,640,640,3)로 입력 가정
    # PyTorch 텐서 (1,3,640,640)를 NumPy로 꺼내고 (1,640,640,3)로 transpose
    tfl_input = image_tensor.cpu().numpy()  # shape (1,3,640,640)
    tfl_input = np.transpose(tfl_input, (0, 2, 3, 1))  # -> (1,640,640,3)
    tfl_input = tfl_input.astype(np.float32)

    # 추론
    interpreter.set_tensor(input_details[0]['index'], tfl_input)
    interpreter.invoke()

    # 출력(9개)
    tflite_outputs = []
    for i in range(len(output_details)):
        out_data = interpreter.get_tensor(output_details[i]['index'])
        tflite_outputs.append(out_data)

    tfl_class_np   = tflite_outputs[0:3]
    tfl_box_np     = tflite_outputs[3:6]
    tfl_center_np  = tflite_outputs[6:9]


    # ------------------------------------------------------
    # (F) 결과 비교: PyTorch vs. ONNX / PyTorch vs. TFLite
    # ------------------------------------------------------
    num_levels = len(pt_class_np)  # 예: 3개 레벨
    for lvl in range(num_levels):
        # --- PyTorch vs. ONNX ---
        mse_class_pt_onnx  = mse(pt_class_np[lvl], onnx_class_np[lvl])
        mse_box_pt_onnx    = mse(pt_box_np[lvl],   onnx_box_np[lvl])
        mse_center_pt_onnx = mse(pt_center_np[lvl],onnx_center_np[lvl])
        
        # --- PyTorch vs. TFLite ---
        # TFLite 출력은 (B,H,W,C) => (B,C,H,W)로 transpose
        tfl_c = tfl_class_np[lvl].transpose(0, 3, 1, 2)
        tfl_b = tfl_box_np[lvl].transpose(0, 3, 1, 2)
        tfl_ce= tfl_center_np[lvl].transpose(0, 3, 1, 2)

        mse_class_pt_tfl  = mse(pt_class_np[lvl], tfl_c)
        mse_box_pt_tfl    = mse(pt_box_np[lvl],   tfl_b)
        mse_center_pt_tfl = mse(pt_center_np[lvl],tfl_ce)
        
        print(f"[Level {lvl+1}]")
        print(f"  PyTorch vs. ONNX:   class={mse_class_pt_onnx:.6f}, "
              f"box={mse_box_pt_onnx:.6f}, centerness={mse_center_pt_onnx:.6f}")
        print(f"  PyTorch vs. TFLite: class={mse_class_pt_tfl:.6f}, "
              f"box={mse_box_pt_tfl:.6f}, centerness={mse_center_pt_tfl:.6f}")
        print()

    ## 출력이 잘 나오는지 확인 (선택)
    # print(pt_class_np[0])
# Out:
# WARNING [01/09 12:00:39 d2.config.compat]: Config './AdelaiDet/configs/FCOS-Detection/FCOS_RT/MS_DLA_34_4x_syncbn.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# [01/09 12:00:39 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./model_final.pth ...
# /opt/anaconda3/envs/detectron2/lib/python3.9/site-packages/fvcore/common/checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# [Level 1]
#   PyTorch vs. ONNX:   class=0.000000, box=0.000000, centerness=0.000000
#   PyTorch vs. TFLite: class=0.000000, box=0.000000, centerness=0.000000
#
# [Level 2]
#   PyTorch vs. ONNX:   class=0.000000, box=0.000000, centerness=0.000000
#   PyTorch vs. TFLite: class=0.000000, box=0.000000, centerness=0.000000
#
# [Level 3]
#   PyTorch vs. ONNX:   class=0.000000, box=0.000000, centerness=0.000000
#   PyTorch vs. TFLite: class=0.000000, box=0.000000, centerness=0.000000
#
# [[[[-3.7475986 -3.4489274 -3.8326697 ... -4.4988065 -4.2263637
#     -4.4829097]
#    [-4.420302  -3.927745  -4.3192916 ... -4.5970197 -4.645439
#     -5.096771 ]
#    [-4.5329003 -4.0292034 -4.0936317 ... -4.634769  -4.646837
#     -5.2706413]
#    ...
#    [-6.1862917 -5.4706616 -6.1654353 ... -4.295063  -4.6587205
#     -4.8525605]
#    [-5.51345   -5.173307  -5.68625   ... -4.224737  -4.4019866
#     -4.849878 ]
#    [-5.1971006 -5.0337186 -5.1431746 ... -4.288286  -4.118121
#     -4.536551 ]]
#
#   [[-4.3797736 -4.7616587 -4.7479086 ... -4.2496867 -4.0466213
#     -4.1999183]
#    [-3.8400028 -4.514032  -4.416393  ... -3.988472  -3.6823637
#     -3.6990137]
#    [-4.2099333 -4.8459225 -4.821731  ... -4.191192  -3.9452145
#     -3.848006 ]
#    ...
#    [-3.4575076 -3.4883804 -3.7040114 ... -4.8648    -4.4506955
#     -4.3394732]
#    [-3.2125916 -3.0345147 -3.0662096 ... -5.0819    -4.7646565
#     -4.3005652]
#    [-3.8037257 -3.7034686 -3.8107514 ... -4.843267  -4.6972213
#     -4.250186 ]]
#
#   [[-4.6895194 -4.5198317 -4.563866  ... -4.501817  -4.748793
#     -5.0737286]
#    [-4.471894  -3.7537694 -3.9663246 ... -3.6056623 -3.6880693
#     -4.8081975]
#    [-4.7150064 -4.104421  -4.2541213 ... -3.3140147 -3.4982045
#     -4.6441846]
#    ...
#    [-5.257727  -3.5289934 -3.7664523 ... -4.6500454 -4.7898655
#     -5.0759163]
#    [-4.9880786 -3.3559718 -3.4389744 ... -4.558564  -4.6983595
#     -5.229696 ]
#    [-5.1737084 -3.83139   -3.7871923 ... -4.590237  -4.5548635
#     -5.000667 ]]]]

# %%
# print(pt_class_np[0])

diff_class = pt_class_np[lvl] - tfl_c  # 예: PyTorch vs. TFLite class logits 비교
print("Max abs diff:", np.max(np.abs(diff_class)))
print("Min abs diff:", np.min(np.abs(diff_class)))
# Out:
# Max abs diff: 4.9114227e-05
# Min abs diff: 0.0
